# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-8, 8, 10001)
y = (np.exp(x) + 1) / x
plt.plot(x, y)
plt.show()
# Out:
# /tmp/ipykernel_6163/2697120896.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   y = (np.exp(x) + 1) / x
